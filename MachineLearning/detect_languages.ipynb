# %% [markdown]
# # Detect Languages

# %%
from utils import *
from load_data import *
from process_data import *
from create_embeddings import *
from split_data import *
from create_model import *
from evaluate_model import *
from run_to_excel import *

import torch
import numpy as np
import pandas as pd
from transformers import BertTokenizer, DistilBertTokenizer, BertModel, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup, RobertaTokenizer, RobertaModel, XLMRobertaModel, AutoTokenizer
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from sklearn.preprocessing import StandardScaler
import re
import string
from gensim.models.fasttext import FastText
from gensim.models import Word2Vec
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from pysentimiento.preprocessing import preprocess_tweet

# %% [markdown]
# ### Preprocessing

# %%
# Load data
data = "data/BBDD_SeAcabo.csv" # "data/BBDD_SeAcabo.csv" "AMI_IBEREVAL2018/es_AMI_TrainingSet_NEW.csv"
df = load_data(data)
# Preprocesado de datos
df['full_text'] = df['full_text'].apply(lambda x: preprocess_tweet(x, lang="es"))
df = process_data(df)

# %% [markdown]
# ### LangDetect

# %%
import langdetect as ld

lang_dict = {}

for i in range(len(df)):
    print(f"{df.iloc[i]['full_text']=}")
    try:
        lang = ld.detect_langs(df.iloc[i]['full_text'])[0]
    except:
        pass

    if lang.lang not in lang_dict.keys():
        lang_dict[lang.lang] = []
    lang_dict[lang.lang].append(i)
    

lang_counts = {}
for lang in list(lang_dict.keys()):
    lang_counts[lang] = len(lang_dict[lang])
# Out:
# df.iloc[i]['full_text']='@usuario TODA ESPAÑA ESTÁ CONTIGO url'
# df.iloc[i]['full_text']='@usuario Espero que te llegue todo el arrope que queremos transmitirte y la admiración por vuestra valentía.'
# df.iloc[i]['full_text']='@usuario No estás sola emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario @usuario Shes a legend .'
# df.iloc[i]['full_text']='@usuario Dilo, reina url'
# df.iloc[i]['full_text']='@usuario Dilo reina, mano dura'
# df.iloc[i]['full_text']='@usuario Las mujeres víctimas de acoso y violencia, NUEVAMENTE, teniendo que ser ELLAS quienes se van de los espacios en los que merecen estar, en lugar de que quienes se vayan sean los agresores.\nUn abrazo y mucha fuerza para ti y todas las jugadoras  emoji corazón morado emoji  emoji manos en oración tono de piel claro emoji  Gracias por no callar.'
# df.iloc[i]['full_text']='@usuario tic tac rubi url'
# df.iloc[i]['full_text']='@usuario url'
# df.iloc[i]['full_text']='@usuario url'
# df.iloc[i]['full_text']='@usuario Todos contigo.'
# df.iloc[i]['full_text']='@usuario Grande Jenni  emoji manos aplaudiendo tono de piel claro emoji  nunca sola  emoji corazón morado emoji  emoji puño en alto tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario Solas no podemos pero juntas si. Estamos todas y todos contigo  emoji corazón morado emoji  emoji bíceps flexionado tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario hashtag se acabó hashtag jenni yo si te creo\n\nY no solo habéis ganado el campeonato del mundo, habéis ganado mucha más\n\nJuntas somos más fuertes   emoji bíceps flexionado tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario Estamos contigo.  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario url'
# df.iloc[i]['full_text']='@usuario Estamos contigo!'
# df.iloc[i]['full_text']='@usuario Estamos contigo, Jenni  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario ESTAMOS TODAS CONTIGO'
# df.iloc[i]['full_text']='@usuario Estamos contigo. Menuda lección has dado, valiente.  emoji bíceps flexionado tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario hashtag seacabo  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario A por el. Hay que echarlo url'
# df.iloc[i]['full_text']='@usuario Grande dentro y fuera de la cancha, esto no se va a repetir más nunca en el mundo deportivo. Hicieron doblemente historia. Que grande es nuestra selección femenina de Fútbol y Campeonas del Mundo.'
# df.iloc[i]['full_text']='@usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario Great response from WorldCup winner  emoji corazón blanco emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario We are with you Hermoso!'
# df.iloc[i]['full_text']='@usuario Un paso muy valiente, Jenni. Que auténtica vergüenza que tengáis que estar soportando este lamentable espectáculo y no disfrutando al 100% de lo que habéis conseguido. Un fuerte abrazo, campeona.'
# df.iloc[i]['full_text']='@usuario hashtag seacabo  emoji corazón morado emoji  emoji corazón morado emoji  SIEMPRE CON VOSOTRAS'
# df.iloc[i]['full_text']='@usuario Espero que se una la selección masculina'
# df.iloc[i]['full_text']='@usuario Todas contigo  emoji bíceps flexionado tono de piel claro emoji  hashtag se acabo'
# df.iloc[i]['full_text']='@usuario Vamosss! Rubiales se tiene que ir a la calle!! \n\nhashtag rubiales acosador'
# df.iloc[i]['full_text']='@usuario @usuario Mucha fuerza'
# df.iloc[i]['full_text']='@usuario No se puede ser más clara y concisa. Desconecta y disfruta de tu victoria, no te preocupes que esto no va a quedar así. Campeona!'
# df.iloc[i]['full_text']='@usuario Estamos contigo  emoji personas abrazándose emoji'
# df.iloc[i]['full_text']='@usuario Estamos todos contigo  emoji manos aplaudiendo tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario Grande.  emoji bíceps flexionado emoji  url'
# df.iloc[i]['full_text']='@usuario Estamos contigo'
# df.iloc[i]['full_text']='@usuario hashtag seacabo  emoji corazón morado emoji  emoji corazón morado emoji  SIEMPRE CON VOSOTRAS !!!'
# df.iloc[i]['full_text']='@usuario @usuario Estamos contigo Jenni  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario Estamos contigo. Estamos con vosotras hashtag seacabo'
# df.iloc[i]['full_text']='@usuario ESTAMOS CONTIGO @usuario! emoji puño en alto tono de piel claro medio emoji  hashtag rubiales inhabilitacion hashtag rubiales acosador'
# df.iloc[i]['full_text']='@usuario Fuerza y ánimo, campeona.\nEstamos contigo.\n emoji rosa emoji  emoji cara lanzando un beso emoji'
# df.iloc[i]['full_text']='@usuario The whole world is with you !!  emoji corazón morado emoji  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario Justice will be served soon...  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario Estamos contigo!!!'
# df.iloc[i]['full_text']='@usuario Acaba con ellos Jenni, estamos contigo'
# df.iloc[i]['full_text']='@usuario Directora de orquesta  emoji violín emoji'
# df.iloc[i]['full_text']='@usuario Nosotras estamos respaldando tu lucha  emoji bíceps flexionado emoji  emoji pulgar hacia arriba emoji'
# df.iloc[i]['full_text']='@usuario Contigo Jenni. Ya basta a ese abuso!  emoji manos en oración tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario Estamos contigo @usuario ¡gracias por tu valentía! Y enhorabuena campeona.'
# df.iloc[i]['full_text']='@usuario @usuario English version?'
# df.iloc[i]['full_text']='@usuario url'
# df.iloc[i]['full_text']='@usuario ¡Estamos contigo!'
# df.iloc[i]['full_text']='@usuario Contigo  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario ESTAMOS CONTIGO JENNI'
# df.iloc[i]['full_text']='@usuario @usuario url'
# df.iloc[i]['full_text']='@usuario CAMPEONA DEL MUNDO, todos contigo emoji bandera españa emoji'
# df.iloc[i]['full_text']='@usuario Estamos contigo hashtag se acabó'
# df.iloc[i]['full_text']='@usuario Gracias @usuario por ser tan valiente!'
# df.iloc[i]['full_text']='@usuario Jenni, sabemos que te están presionando desde el Gobierno y los medios. \n\nEn el Partidazo de la Cope diste una versión completamente, distinta, te recomiendo que cambies de asesores urgentemente. url'
# df.iloc[i]['full_text']='@usuario ¿Quién te ha presionado para hacer este comunicado? Y por cierto el que te ha escrito este comunicado que lo revise y corrija las faltas ortográficas que hacen daño a la vista.\nEste comunicado, el domingo pasado, no ahora.\nQue triste todo, se ha hablado más del beso que de'
# df.iloc[i]['full_text']='@usuario hashtag se acabó hashtag rubiales destitucion ya'
# df.iloc[i]['full_text']='@usuario Estamos contigo!, no estás sola! hashtag se acabo  emoji corazón morado emoji   emoji teléfono emoji 016 emoji teléfono emoji'
# df.iloc[i]['full_text']='@usuario @usuario Estamos contigo Jenni  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario - Paritat absoluta a totes les federacions esportives !\n- Regeneració dels dinosaures dirigents.\n- Codi ètic i de conducta exemplar.\n- Equips mixtes ja !'
# df.iloc[i]['full_text']='@usuario More power to you  emoji bíceps flexionado emoji   We are behind  emoji pulgar hacia arriba emoji'
# df.iloc[i]['full_text']='@usuario No solo tiene que dimitir el calvo, tienen que salir todos los que han participado en presionar a la familia de una jugadora para salvar el cuello de su presi.'
# df.iloc[i]['full_text']='@usuario Estamos contigo  emoji puño en alto tono de piel oscuro medio emoji'
# df.iloc[i]['full_text']='@usuario Todo México contigo.  emoji bandera méxico emoji  emoji bandera españa emoji'
# df.iloc[i]['full_text']='@usuario I dont understand this but I support you 1million percent'
# df.iloc[i]['full_text']='@usuario "Ella atrajo su cuerpo hacia mi"- Rubiales. \n" Ella ya lo había hecho antes"\n" Su falda era muy corta" \n" Para que te vistes así, te lo buscaste"\n"La que busca encuentra"\nElla, ella, ella, ella siempre es ella la culpable ellos las pobres víctimas ... y con el aplauso de esos'
# df.iloc[i]['full_text']='@usuario Segura?\n\nAl menos que esto sirva para que rubiales y a toda la mafia de la federación dimitan..\n\nurl'
# df.iloc[i]['full_text']='@usuario Teníamos muchas ganas de verte salir a defenderte. Es muy injusto todo lo que está pasando. Rubiales tiene que ser destituido. Estamos contigo y con todas Jenni en esto.'
# df.iloc[i]['full_text']='@usuario IMPULSORAS DEL ME TOO en el futbol femenino!!  emoji mano haciendo el signo de cuernos tono de piel claro medio emoji  emoji mano haciendo el signo de cuernos tono de piel claro medio emoji  emoji mano haciendo el signo de cuernos tono de piel claro medio emoji \n\nQue arda TROYA!!!  emoji fuego emoji  emoji fuego emoji  emoji fuego emoji'
# df.iloc[i]['full_text']='@usuario @usuario hashtag seacabo  emoji corazón morado emoji  emoji corazón morado emoji  SIEMPRE CON VOSOTRAS !!'
# df.iloc[i]['full_text']='@usuario hashtag seacabo Apoyo total y un abrazo inmenso desde México'
# df.iloc[i]['full_text']='@usuario Mucha fuerza'
# df.iloc[i]['full_text']='@usuario @usuario pensaba que eras el reven y digo "coño que reformed está de repente"  emoji cara llorando fuerte emoji'
# df.iloc[i]['full_text']='@usuario ERES UNA LEYENDA, JENNI. emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón morado emoji  emoji bíceps flexionado tono de piel claro medio emoji  emoji fuego emoji'
# df.iloc[i]['full_text']='@usuario Y que conste que Rubiales no debería estar donde está por todos los casos de corrupción y en compañía del Tito Berni, pero no fue así, lo del beso, no sé justifica, pero fue en un acto de grandes emociones, yo no lo hubiera hecho...\nDespués de toda la semana con el beso en todos url'
# df.iloc[i]['full_text']='@usuario Estamos contigo Jenni  emoji puño en alto emoji'
# df.iloc[i]['full_text']='@usuario He must Resign'
# df.iloc[i]['full_text']='@usuario Eres una VALIENTE. Estamos contigo!  \nhashtag jenninoestassola'
# df.iloc[i]['full_text']='@usuario Vuela alto Rubiales  emoji paloma emoji  url'
# df.iloc[i]['full_text']='@usuario  emoji corazón rosa emoji  emoji corazón rosa emoji  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Al teu costat @usuario hashtag se acabo hashtag prou'
# df.iloc[i]['full_text']='@usuario Estamos contigo campeona'
# df.iloc[i]['full_text']='@usuario Tienes detrás a un país apoyándote, adelante  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario Necesitamos mejorar los procesos de fiscalización a los dirigientes con la participación de los aficionados. Con voz y voto.\n¡Estamos contigo!\nhashtag se acabó'
# df.iloc[i]['full_text']='@usuario Qué triste que las feministas te hayan hecho renunciar a la alegría de la victoria por tremenda tontada. Y que no hayas tenido valor de enfrentarlas.'
# df.iloc[i]['full_text']='@usuario Ánimo, Jenn, estamos contigo &lt;3'
# df.iloc[i]['full_text']='@usuario Solo con esto ya debe estar fuera. Una autoridad sin educación básica no pude seguir en su puesto. url'
# df.iloc[i]['full_text']='@usuario "En ningún caso busqué alzar al presidente" url'
# df.iloc[i]['full_text']="@usuario I can't read Spanish...\n\n But he must Resign!!!  No other way out"
# df.iloc[i]['full_text']='@usuario No puede ser más clara  emoji manos aplaudiendo tono de piel claro emoji   emoji manos aplaudiendo tono de piel claro emoji  hashtag se acabo'
# df.iloc[i]['full_text']='@usuario Jennifer Hermoso, NUNCA TE VAMOS A SOLTAR LA MANO, JAMÁS VAMOS A DEJAR DE LUCHAR A TU LADO, HASTA LA ETERNIDAD METIENDO GOLAZOS FEMINISTAS hashtag se acabó hashtag me too hashtag periodismo machista hashtag rubiales destitución hashtag rubiales dimisión hashtag rubiales out hashtag rubiales agresor hashtag rfef hashtag jenni hashtag jenni hermoso'
# df.iloc[i]['full_text']='@usuario Goool grande Jenni  emoji manos aplaudiendo tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario Mucho ánimo. Estamos contigo.'
# df.iloc[i]['full_text']='@usuario Estamos con vosotras y contigo! Ánimo  emoji estrella emoji'
# df.iloc[i]['full_text']='@usuario mucha fuerza y ánimos! con vosotras!  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario hashtag yosicreoenrubiales'
# df.iloc[i]['full_text']='@usuario Pues no hay mucho más que decir, porque si el sujeto pasivo de la acción asegura que no hubo consentimiento, es que seguramente no lo hubo o que, de haberlo, este fue aparente, forzado o lo que en Derecho se denomina "viciado".'
# df.iloc[i]['full_text']='@usuario Pues si consideras que es una agresión, das muy mal ejemplo a todas las mujeres al no denunciarlo. \nEs así de sencillo.'
# df.iloc[i]['full_text']='@usuario Siempre contigo, Jenni'
# df.iloc[i]['full_text']='@usuario  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario Todos contigo emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario Estamos contigo. Estos hechos no pueden quedar sin consecuencia.'
# df.iloc[i]['full_text']='@usuario Efectivamente se acabó... ver fútbol femenino.\nA ver si lo entendéis de una vez, todo lo que toca la izquierda LO PUDRE. \nAhora que la liga femenina levanta cabeza y se ha logrado un mundial, llega esto para separar a los seguidores. \nNo lo queréis entender, allá vosotras.'
# df.iloc[i]['full_text']='@usuario locas de twitter, ya lo dijo ricky edit'
# df.iloc[i]['full_text']='@usuario BRAVO!!'
# df.iloc[i]['full_text']='@usuario url'
# df.iloc[i]['full_text']='@usuario Aprovechando la repercusión de un pico a esta chica en la celebración de ganar el mundial, voy a poner dos noticias que no llevan días,ni semanas abriendo y cerrando programas ni telediarios. Tampoco hay asociaciones ni peces gordos ni feministas pidiendo justicia y protección url'
# df.iloc[i]['full_text']='@usuario Al juzgado a denunciar Jenni, con tus propias declaraciones y con las imágenes que están saliendo.\n\nA ver si tienes ovarios.\n\nSpoiler: NO LO HARÁS.'
# df.iloc[i]['full_text']='@usuario Estamos contigo.\nhashtag se acabó'
# df.iloc[i]['full_text']='@usuario @usuario no entiende que las mujeres no las ven,las ven hombres y los estan echando a todos'
# df.iloc[i]['full_text']='@usuario Eres una auténtica mentirosa, está todo grabado y tendrás que defenderlo ante un juez.\n\nHas ensuciado la victoria de la selección y la imagen de nuestro país. url'
# df.iloc[i]['full_text']='@usuario Todos contigo. Bravo  emoji manos aplaudiendo tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario DILO MAS ALTO, REINA!  emoji corona emoji \n\nTodos mis animos ante estas presiones dificiles de soportar.'
# df.iloc[i]['full_text']='@usuario Pensaba que estaba leyendo a @usuario'
# df.iloc[i]['full_text']='@usuario Luis Rubiales manipulador: "El beso fue espontáneo, mutuo y consentido". Ella me dijo eres un crack, yo le dije ¿un piquito? y sucedió.\n\nMentiroso. url'
# df.iloc[i]['full_text']='@usuario  emoji puño en alto emoji  url'
# df.iloc[i]['full_text']='@usuario Madre del amor hermoso, esto no lo lee ni clifford.'
# df.iloc[i]['full_text']='@usuario Nada mas que decir\n\nCon este comunicado, Jenni Hernoso deja claro que Rubiales actuó mal y se sobrepasó.\n\nHuele bastante mal todo lo que rodea a la federación hace años, asi que sería un buen momento para renovar a un equipo que tiene que ayudar a grandes deportistas'
# df.iloc[i]['full_text']='@usuario @usuario Tal cual. Tristísimo.'
# df.iloc[i]['full_text']='@usuario Nada mas que añadir, absolutamente todo dicho.'
# df.iloc[i]['full_text']='@usuario Espero que rueden cabezas y que no se te cuestione ni un segundo, este comunicado tiene que llegar al fin del mundo! url'
# df.iloc[i]['full_text']='@usuario Estamos contigo, Jenni \n\nSois todas unas valientes y tiene un mérito increíble lo que habéis conseguido pese a un entorno tan dañino.\n\nOjalá pronto solo os tengáis que preocupar de jugar, de nada más.'
# df.iloc[i]['full_text']='@usuario Nada más que añadir, solo queda que se haga justicia y sirva de ejemplo para el futuro!  emoji balanza emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario Ahora dices que esa era tu gemela malvada. url'
# df.iloc[i]['full_text']='@usuario La pelota siempre a la 10.'
# df.iloc[i]['full_text']='@usuario Estamos contigo'
# df.iloc[i]['full_text']='@usuario He aqui un ejemplo de lo hipócritas que sois. url'
# df.iloc[i]['full_text']='@usuario hashtag se acabo'
# df.iloc[i]['full_text']='@usuario Eres una jefa!'
# df.iloc[i]['full_text']='@usuario Es inadmisible el comportamiento del presidente del RFEF.'
# df.iloc[i]['full_text']='@usuario url'
# df.iloc[i]['full_text']='@usuario Por estas cosas no toman a las mujeres en cuenta. Victimizais un acto de tremenda alegría. Los hombres no hacen esto si es al contrario. No me extraña que cada día quieran menos a una mujer cerca,parecemos de mantequilla. Que vergüenza'
# df.iloc[i]['full_text']='@usuario Jenni con todo el respeto del mundo, ¿agresión? Por favor...'
# df.iloc[i]['full_text']='@usuario hashtag seacabo'
# df.iloc[i]['full_text']='@usuario RUBIALES saca los audios de la PSOE antes de que sea tarde.'
# df.iloc[i]['full_text']='@usuario Jaque mate al cavernícola. emoji fuego emoji  url'
# df.iloc[i]['full_text']='@usuario Estas escupiendo sobre miles de mujeres violadas y agredidas sexualmente en el mundo si consideras que este pico amistoso como bien dijiste en un primer momento en todas tus entrevistas,  es una agresión sexual. No sé cómo no se te cae la cara de vergüenza!'
# df.iloc[i]['full_text']='@usuario Todos estamos contigo url'
# df.iloc[i]['full_text']='@usuario ESTAMOS CONTIGO url'
# df.iloc[i]['full_text']='@usuario Que bien te lo han redactado, mas bien la presion ha sido por parte del las feminazis'
# df.iloc[i]['full_text']='@usuario We werent in the MLS at 35 url'
# df.iloc[i]['full_text']='@usuario Estos son los que se escandalizan por rubiales url'
# df.iloc[i]['full_text']='@usuario @usuario ¡Fuerza, Jenni!'
# df.iloc[i]['full_text']='@usuario Por fin! Ahora si! Apoyo a hierro!'
# df.iloc[i]['full_text']="@usuario Hey, here is an English Translation for  y'all \nWhat do you think about this? url"
# df.iloc[i]['full_text']='@usuario English translation url'
# df.iloc[i]['full_text']='@usuario Bravísima Jenni! Estamos contigo. Ni un paso atrás contra este supremacismo machista. hashtag se acabó hashtag me too hashtag rubiales out'
# df.iloc[i]['full_text']='@usuario Una vergüenza Rubiales.'
# df.iloc[i]['full_text']='@usuario ¿Se puede ser más patético?, aunque tengo mis reservas sobre la veracidad de la foto, ¿Qué más da si @usuario lo levantó del suelo o fue su cuñado aficionado al Photoshop?   \n\nLa cuestión es que:   \n\nPRIMERO: NO se puede ser tan zafio para agarrarse el paquete en un palco,'
# df.iloc[i]['full_text']='@usuario url'
# df.iloc[i]['full_text']='@usuario @usuario Aunque supongo que no es fácil todo lo que estarás pasando gracias por ser tan valiente  emoji corazón rojo emoji  emoji rosa emoji'
# df.iloc[i]['full_text']='@usuario Tienes que entrenar el lanzamiento de penalties. Lo lanzaste fatal...'
# df.iloc[i]['full_text']='@usuario @usuario Idiota.'
# df.iloc[i]['full_text']='@usuario Este caradura las explicaciones que da de que fue un beso consentido son pateticas  y demuestran lo mentiroso y cínico que es ! Toda españa vio que fue un beso totalmente robado y sin pedir permiso como el dice , y la historía que se inventó cuando se tocó sus partes diciendo que'
# df.iloc[i]['full_text']="@usuario Felicidades por el éxito deportivo. Y por el abuso y agresión recibida, todo mi apoyo en la denúncia que realizas. Valiente dentro y fuera de campo. P'alante!!"
# df.iloc[i]['full_text']='@usuario que opinas de mi once para esta jornada? url'
# df.iloc[i]['full_text']='@usuario Tiene que dimitir ese enfermo.'
# df.iloc[i]['full_text']='@usuario  emoji manos levantadas celebrando emoji  emoji manos levantadas celebrando emoji  emoji manos levantadas celebrando emoji  Todas estamos contigo.'
# df.iloc[i]['full_text']='@usuario @usuario Mi solidaridad con usted. url'
# df.iloc[i]['full_text']='@usuario Viendo el vídeo pienso lo siguiente:\n\nSi eres el "jefe" encargado o lo que quieras llamarlo, no puedes actuar así. Quitemos lo de feminismo por un momento y todo ese tema. \nEres el jefe de un equipo , puede haber cercanía entre las jugadoras y tú, pero en un acto oficial te'
# df.iloc[i]['full_text']='@usuario Se te veia muy en shock...si...'
# df.iloc[i]['full_text']='@usuario Eres muy grande @usuario. Sabemos que estás sufriendo, pero tu valentía ayudará mucho a todas las mujeres de este país para que no se repitan este tipo de actos machistas, prepotentes e intolerables. Gracias y mucho ánimo.'
# df.iloc[i]['full_text']='@usuario Leyenda!'
# df.iloc[i]['full_text']='@usuario  emoji corazón rosa emoji  emoji manos formando un corazón tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario url'
# df.iloc[i]['full_text']='@usuario Que se te recordase como la que fallo el penalti hubiese sido jodido pero al menos estaría ligado a que fuiste campeona del mundo, ahora solo se te recordara como la petarda a la que le dio un pico Rubiales, disfruta.'
# df.iloc[i]['full_text']='@usuario url'
# df.iloc[i]['full_text']='@usuario Eres una camionera mentirosa y mala persona: aquí está la secuencia de fotos que  desmienten tus palabras\n\n"Quiero aclarar que en ningún momento consentí el beso que me propinó y en ningún caso busqué alzar al presidente. No tolero que se ponga en duda mi palabra y mucho menos url'
# df.iloc[i]['full_text']='@usuario Trilera...'
# df.iloc[i]['full_text']='@usuario Jenni yo te quiero, Jenni yo te adoro!!! Y las cerves ya te esperan  emoji jarra de cerveza emoji'
# df.iloc[i]['full_text']='@usuario Cobarde'
# df.iloc[i]['full_text']='@usuario @usuario no sólo es un acto repleto de valentía lo que acabas de hacer, sino de profunda solidaridad y generosidad con las mujeres que no tienen los medios para denunciar algo qué pasa todos los días y es absolutamente inaceptable el acoso y el hostigamiento sexual hashtag se acabo'
# df.iloc[i]['full_text']='@usuario Cualquier cosa en que pueda ser de provecho, un dm.\n\nNo te arrugues.\nAquí tienes una que va detrás tuyo y no va a girarse.\n\nSi tú no lo haces, yo tampoco.\nHazlo bien.  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario Pues no se ve muy acosada... Es más lo disfrutan y piden más.. url'
# df.iloc[i]['full_text']='@usuario  emoji bíceps flexionado tono de piel oscuro medio emoji'
# df.iloc[i]['full_text']='@usuario Si por eso lo levantaste en el aire tú y no él a ti. Una cosa que aclara la ley del si es si es que aunque te lo estás inventando y has dado una vuelta de 180, cualquier hombre está a la merced de una mujer que decide hacer lo contrario de lo ha hecho en un primer momento. Te'
# df.iloc[i]['full_text']='@usuario Al menos podrías haber escrito el comunicado sin faltas de ortografía.\nOtra chufla más.'
# df.iloc[i]['full_text']='@usuario Ten cuidado que no se puede mentir delante de un juez, mira lo que le pasó a Juana Rivas'
# df.iloc[i]['full_text']='@usuario Como mujer creo que os estáis pasando tres pueblos no se que rédito queréis conseguir \nPor un beso entre adultos \nEra  tu colega o no ?\nAhora es un desconocido\nTu ves normal este revuelo \nFelicidades por poner a España en el punto de mira y vuestra copa \nQuede subsuelo'
# df.iloc[i]['full_text']='@usuario Te joden la celebración del mundial los falsos feministas y los medios de desinformación y tu les sigues la bola. Eres mala y cortita. Menuda carabanchelera'
# df.iloc[i]['full_text']='@usuario @usuario Bonito comunicado !'
# df.iloc[i]['full_text']='@usuario Estamos contigo \nhashtag se acabó'
# df.iloc[i]['full_text']='@usuario Vete a un Juzgado entonces. No lo harás porque sabes que es mentira.'
# df.iloc[i]['full_text']='@usuario @usuario Si lo hubieras deseado tanto lo del beso lo hubieras zanjado ese dia pero solo queriais salir en la tele enhorabuena ahora vive con tus elecciones nefastas no se como no te recomcome destrozar una vida sin fuste alguno mala persona eres eeh'
# df.iloc[i]['full_text']='@usuario ¿Y esto?\nDe no darle importancia a convertir a un hombre en el protagonista.\nVergüenza ajena. url'
# df.iloc[i]['full_text']='@usuario hashtag se acabo\nPor vosotras.\nPor nosotros.\nPor las que estuvisteis, por las que estáis y por las que estarán.\nDeporte es igualdad.'
# df.iloc[i]['full_text']='@usuario @usuario ¿Qué país?'
# df.iloc[i]['full_text']='@usuario Este es el comunicado con el cual se puede limpiar uno el ojete ¿no? ¡Que triste!'
# df.iloc[i]['full_text']='@usuario Que asco das !  emoji cara vomitando emoji  por tu culpa has jodido el éxito de tus compañeras por unos días de casito mediático ! Eso y reírte en la cara de las mujeres que si han sido forzadas y violadas! Eres deleznable !!'
# df.iloc[i]['full_text']='@usuario Ole tú.\n\nHiciste muy bien en pasar de movidas y celebrar la hazaña que conseguistéis como se merecía.\n\nY ahora haces muy bien haciendo público tu repulsa por esa actuación impresentable  y reprobables.. y todas las presiones  recibidas\n\n¿Le hubiera dado un morreo a Iniesta?'
# df.iloc[i]['full_text']='@usuario Vete a la mierda, Jenny, vete a la mierda...'
# df.iloc[i]['full_text']='@usuario Yo no apoyo a Rubiales por qué eso no está bien, pero tú con lo de ser famosa estáis haciendo una drama de una gilipollez, no te gustaría verte violada y golpeada como las verdaderas víctimas de violencia de género, ahora se me echarán encima las feminazis pero las cosas como son'
# df.iloc[i]['full_text']='@usuario Estamos contigo guapa.'
# df.iloc[i]['full_text']='@usuario Pedazo de poca mujer te mereces una bofetada por falsa y no un puñetero beso. Que tan mal tiene que estar tu cabeza para montar un puto follón por un simple beso. Irrespeto es que te agredan no que te besen pedazo de decepción con patas.'
# df.iloc[i]['full_text']='@usuario Psicópata'
# df.iloc[i]['full_text']='@usuario Que bueno que te marchas de la selección  emoji dorso de mano con índice a la derecha tono de piel claro medio emoji  Aparte de mala jugadora, también hdp! Sabes que hashtag rubiales no actúo con mala intención pero ahora ya no puedes echar para atrás así dejes a un lado los valores y principios morales. Que hdp  emoji dedo corazón hacia arriba tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario Es una vergüenza que te dejes manipular así por ese sindicato de feminazis, tu misma has reconocido públicamente en la Cope y en diversos videos que fue consentido y que no tenia importancia y ahora vas de victima de violación. Esto te va a acompañar toda la vida, Jenni mentirosa'
# df.iloc[i]['full_text']='@usuario Oye, yo creo que tú de feminista tienes bien poco, estás burlándote de tantas mujeres maltratadas y asesinadas cada año, denunciando algo ridículo que tú misma dijiste que fue consentido aunque no te gustara y que fue un gesto por la efusividad del momento, eres ridícula.  emoji reloj de arena con tiempo emoji  emoji cabeza parlante emoji  url'
# df.iloc[i]['full_text']='@usuario Que pena, que gente más estúpida. Si Brasil , Argentina o Colombia hubiesen ganado el mundial les habría importado un carajo ese lindo beso que recibió la jugadora. \nEl carnaval estaría de pleno festejando la corona mundial. \nEstos españoles idiotas se cagaron ellos mismos.'
# df.iloc[i]['full_text']='@usuario Te cargaste el fútbol femenino por venderte como ganado a las garras feministas de ultra izquierda . Das mucho asco por tu hipocresía'
# df.iloc[i]['full_text']='@usuario Eres una choni mentirosa, falsa y sectaria, y te has vendido a la ideología feminista en el último minuto por un momento de gloria mediática que vas a pagar muy cara porque la gente no es idiota, aunque te hayan vendido que sí, y sabe perfectamente discernir el bien del mal. ASCO'
# df.iloc[i]['full_text']='@usuario Mentirosa, sal y di la verdad, ahora te conocerán por la chica del beso envéz de por la chica que ganó un mundial, Sinvergüenza url'
# df.iloc[i]['full_text']='@usuario no tienes vergüenza... eres gentuza de la peor calaña'
# df.iloc[i]['full_text']='@usuario Jenniii, a chuparla la vieja esa. Aquí la verdad sabemos todos cual es. Fuerza!!'
# df.iloc[i]['full_text']='@usuario Pide respeto cuando digan la verdad!. Trepas y mentirosas!. Ustedes se están riendo de las que SI han sido violadas y abusadas sexualmente. Son una vergüenza!! url'
# df.iloc[i]['full_text']='@usuario Mucha Fuerza Jenni!\nÉste es un Patán Machista y Miserable que con el resto de acciones vergonzosas durante y al final del partido, no deja lugar a dudas de su asquerosa conducta.'
# df.iloc[i]['full_text']='@usuario Eres una mentirosa. Espero que te lleven a juicio y pagues por todo el daño que estas haciendo.'
# df.iloc[i]['full_text']='@usuario Que asco de persona, robot programado. Yo no veo una campeona, veo a la peor versión de una mujer.'
# df.iloc[i]['full_text']='@usuario Sinvergüenza!!! Mentirosa, jugar con algo tan serio. Se te tendría que caer la cara de vergüenza  emoji cara cabreada emoji  emoji cara con símbolos en la boca emoji'
# df.iloc[i]['full_text']='@usuario Eres una falsa, aprovechadora y oportunista'
# df.iloc[i]['full_text']='@usuario this just another feminazi stunt. Until men will step aside for a while, leaving women to deal with this toxic movment, this will not stop.'
# df.iloc[i]['full_text']='@usuario Te has cargado tu propia carrera, por payasa máxima.'
# df.iloc[i]['full_text']='@usuario @usuario No tenéis vergüenza,  ni tú ni tus compañeras. Por mi puede desaparecer el fútbol femenino, habéis entrado en un juego político por no tener dos ovarios bien puestos. Sois basura ni hombres ni mujeres, sois basura de personas TÚ Y TUS COMPAÑERAS.'
# df.iloc[i]['full_text']='@usuario Prepárense para "Joga Bonito" x si no te Piqué sin Culé,\nPero tengo mas hambre q el waka waka motakunka pa q después un distintivo en pantalones ni se disimule emoji manos formando un corazón emoji \u200d emoji fuego emoji  emoji estatua moái emoji  emoji genio emoji \u200d emoji globo terráqueo con meridianos emoji'
# df.iloc[i]['full_text']='@usuario @usuario Hay que acabar con el url'
# df.iloc[i]['full_text']='@usuario @usuario Lamentable lo de Rubi url'
# df.iloc[i]['full_text']='@usuario @usuario Es increíble, que tiene que pasar en este país para que dimita alguien?'
# df.iloc[i]['full_text']='@usuario @usuario Dilo reina!  emoji manos levantadas celebrando tono de piel claro emoji  url'
# df.iloc[i]['full_text']='@usuario @usuario Lo más graves es que parte de la selección mostró su rechazo hacia esa persona. Compañeras se perdieron el mundial por culpa de este sin vergüenza y ahora en lugar de agachar cabeza e irse sin hacer ruido esto no representa a España este tio. \nMucho animo chicas, estamos con'
# df.iloc[i]['full_text']='@usuario @usuario @usuario url'
# df.iloc[i]['full_text']='@usuario @usuario Esto es la guerra. Estamos en vuestro equipo.'
# df.iloc[i]['full_text']='@usuario @usuario En esto no hay colores\nValores  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario @usuario Reina  emoji corona emoji'
# df.iloc[i]['full_text']='@usuario @usuario Valors  emoji manos aplaudiendo tono de piel claro emoji  url'
# df.iloc[i]['full_text']='@usuario @usuario Pierdan el miedo, mujeres y hombres. Es el momento. Vamos.'
# df.iloc[i]['full_text']='@usuario @usuario My captain  emoji manos levantadas celebrando tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Con Ustedes  emoji fuego emoji  emoji fuego emoji  emoji fuego emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Ustedes  emoji corona emoji  emoji cara saludando emoji  url'
# df.iloc[i]['full_text']='@usuario @usuario Eres la mejor, CAPITANA.'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario Valientes.'
# df.iloc[i]['full_text']='@usuario @usuario Doña'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corona emoji'
# df.iloc[i]['full_text']='@usuario @usuario Acabad con el'
# df.iloc[i]['full_text']='@usuario @usuario We are also with you  emoji manos formando un corazón emoji  emoji pulgar hacia arriba emoji'
# df.iloc[i]['full_text']='@usuario @usuario Gracias @usuario, entre todos y todas vamos a echar al machista neardental de Rubiales. hashtag rubiales cese'
# df.iloc[i]['full_text']='@usuario @usuario Ahora sí. ¡Enorme Alexia!'
# df.iloc[i]['full_text']='@usuario @usuario ALEXIIIA no podia fallar.'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Tod@usuario los jugadores y entrenadores deberían de presentar su renuncia.'
# df.iloc[i]['full_text']='@usuario @usuario url'
# df.iloc[i]['full_text']='@usuario @usuario Testimo'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos formando un corazón emoji'
# df.iloc[i]['full_text']='@usuario @usuario Con vosotras, campeonas  emoji manos formando un corazón tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Estamos con vosotras  emoji bíceps flexionado emoji  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario Oye que de esto no habla o que, la cara tú emoji calavera emoji  url'
# df.iloc[i]['full_text']='@usuario @usuario Reúne a los vengadores y acaba con Thanos'
# df.iloc[i]['full_text']='@usuario @usuario No estáis solas  emoji corazón rojo emoji'
# df.iloc[i]['full_text']='@usuario @usuario buenas alexia soy roncho'
# df.iloc[i]['full_text']='@usuario @usuario Dilo Reina'
# df.iloc[i]['full_text']='@usuario @usuario No se qué tiene que pasar para que alguien dimita en este pais'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario Eres la mejor  emoji corazón azul emoji  emoji corazón rojo emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Venga. Ahora en la empresa privada también, que esta ha sido fácil.'
# df.iloc[i]['full_text']='@usuario @usuario Tú también tienes nuestro respaldo  emoji bíceps flexionado emoji  emoji pulgar hacia arriba emoji'
# df.iloc[i]['full_text']='@usuario @usuario Sempre al vostre costat i amb totes vosaltres. Fins on calgui! emoji bíceps flexionado tono de piel claro emoji  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Así si Alexia, todos estamos con vosotras'
# df.iloc[i]['full_text']='@usuario @usuario Eres tú!  emoji corona emoji'
# df.iloc[i]['full_text']='@usuario @usuario Ojalá lo consigáis todas juntas'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corona emoji  emoji corona emoji  emoji corona emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario En esto no hay colores.. vamos  emoji bíceps flexionado tono de piel claro medio emoji \n\nhashtag rubiales dimisión ya'
# df.iloc[i]['full_text']='@usuario @usuario url'
# df.iloc[i]['full_text']='@usuario @usuario BRAVO  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario Acabad con él.'
# df.iloc[i]['full_text']='@usuario @usuario Todo nuestro apoyo Reina  emoji bíceps flexionado emoji  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario Maestra'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Mas populismo!'
# df.iloc[i]['full_text']='@usuario @usuario @usuario  url'
# df.iloc[i]['full_text']='@usuario @usuario  emoji estrella brillante emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji bíceps flexionado emoji  emoji bíceps flexionado emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario Bien Alexia'
# df.iloc[i]['full_text']='@usuario @usuario Estamos todos juntos en esta lucha, ¡ya basta! Este tipo de situación ya no será aceptada.'
# df.iloc[i]['full_text']='@usuario @usuario Con todo. url'
# df.iloc[i]['full_text']='@usuario @usuario ALEXIAAA. ERES GRANDEEE  emoji manos aplaudiendo tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario MY Captain  emoji estrella emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario CON VOSOTRAS  emoji corazón morado emoji  emoji pulgar hacia arriba emoji  emoji bíceps flexionado emoji  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario url'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji cabra emoji  emoji cabra emoji  emoji cabra emoji'
# df.iloc[i]['full_text']='@usuario @usuario A por ese mamonazo'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario Quieres otro balón de oro regalado eh.'
# df.iloc[i]['full_text']='@usuario @usuario the queen has spoken'
# df.iloc[i]['full_text']='@usuario @usuario Tebas and rubiales should resign today'
# df.iloc[i]['full_text']='@usuario @usuario @usuario  emoji manos aplaudiendo tono de piel medio emoji  emoji manos aplaudiendo tono de piel medio emoji  emoji manos aplaudiendo tono de piel medio emoji  emoji manos aplaudiendo tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Todos estamos con vosotras, esto es una auténtica verguenza. CAPITANA emoji corazón azul emoji'
# df.iloc[i]['full_text']='@usuario @usuario LFGGG'
# df.iloc[i]['full_text']='@usuario @usuario CAPITANA  emoji corazón con flecha emoji'
# df.iloc[i]['full_text']='@usuario @usuario Dilo, Alexia.'
# df.iloc[i]['full_text']="@usuario @usuario Dale ma' confía en mí\nYo no soy tan malo como dicen\nNo dejes que los hechos te aterroricen\nDeja que mis manos en tu espalda aterricen\nQue el olor de mis sábanas te hechice\n\nQue tu nivel haciéndolo\nEntre cuatro paredes divirtiéndonos\nPide lo que quieras que esto no puede ser más url"
# df.iloc[i]['full_text']='@usuario @usuario Fracasada'
# df.iloc[i]['full_text']='@usuario @usuario @usuario  emoji manos formando un corazón tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario El tratamiento no es lo mismo cuando Somos mujeres  emoji cara vomitando emoji  emoji cara vomitando emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande reina hay que acabar con el'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji pulgar hacia arriba tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario @usuario Bravo La Reina  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario Tu lo que quieres es otro balón de oro regalado al ir de Gandhi.'
# df.iloc[i]['full_text']="@usuario @usuario Come on world  emoji globo terráqueo mostrando américa emoji  let's join to support them  emoji pulgar hacia arriba emoji  Women in sports struggle a lot to come in.. And once they are in, they again face struggles like this  emoji persona con la mano en la frente tono de piel claro emoji"
# df.iloc[i]['full_text']='@usuario @usuario @usuario url'
# df.iloc[i]['full_text']='@usuario @usuario eres la mejor'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Contigo capitana...'
# df.iloc[i]['full_text']='@usuario @usuario Jefa!!!'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji   emoji cabeza parlante emoji  emoji cabeza parlante emoji  emoji corona emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario REINA'
# df.iloc[i]['full_text']='@usuario @usuario Todas juntas tenéis que sacar a estos ineptos de ahí... Que rezón teníais...'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario @usuario Bravas emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji cabra emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande Alexia. emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario url'
# df.iloc[i]['full_text']='@usuario @usuario Madre'
# df.iloc[i]['full_text']="@usuario @usuario @usuario Tout a fait d'accord url"
# df.iloc[i]['full_text']='@usuario @usuario Planificando el contraataque?'
# df.iloc[i]['full_text']='@usuario @usuario url'
# df.iloc[i]['full_text']='@usuario @usuario Doña.'
# df.iloc[i]['full_text']='@usuario @usuario Oportunista, lerda y oveja.'
# df.iloc[i]['full_text']='@usuario @usuario Bravooo  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Estamos con vosotras  emoji puño en alto tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Estamos contigo capitana'
# df.iloc[i]['full_text']='@usuario @usuario Inaceptable compañera emoji dorso de mano con índice hacia abajo emoji \nurl'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel medio emoji  emoji manos aplaudiendo tono de piel medio emoji  emoji manos aplaudiendo tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Esto son valores!! emoji manos levantadas celebrando tono de piel claro emoji  Muy grande  emoji estrella emoji'
# df.iloc[i]['full_text']='@usuario @usuario Ahora si habla, cuando en la celebración no quizo hacerlo!!  emoji cara con ojos en blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Tienes amigas lindas de 22-24?'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario Rubiales aguantando por lo civil o lo criminal en su puesto: url'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario A muerte con vosotras.'
# df.iloc[i]['full_text']='@usuario @usuario Quien levanta a quien..en el contexto de esta imagen lo siguiente es un beso no una agresion sexual!. Y q quede claro ,rubiales es un prepotente mal educado!\nY deveria dimitir !\nNuestros politicos son buitres!\nJAMAS eso beso es agresion sexual\nEspańa es la ostia! url'
# df.iloc[i]['full_text']='@usuario @usuario HIJA ETERNA DE DON JORGE VILDA url'
# df.iloc[i]['full_text']="@usuario @usuario Show it. Don't play for Spain until Rubi resigns."
# df.iloc[i]['full_text']='@usuario @usuario Grandeee emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario Es el camino. Con vosotras.'
# df.iloc[i]['full_text']='@usuario @usuario Y luego lo llama feminismo "falso". Muy falso no será en el momento que toda España clama hashtag dimisionrubiales'
# df.iloc[i]['full_text']='@usuario @usuario Es increible!'
# df.iloc[i]['full_text']='@usuario @usuario He will be gone by the end of the month. Keep putting the pressure on them!'
# df.iloc[i]['full_text']='@usuario @usuario Bravaaa  emoji personas abrazándose emoji ...Permitir una injusticia significa abrir el camino a todas las que siguen.'
# df.iloc[i]['full_text']='@usuario @usuario Totalmente de acuerdo hay que acabar con toda falta de resperto hacia las personas url'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario Se vienen cositas  emoji fuego emoji  emoji fuego emoji  emoji fuego emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario A por ellos  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  url'
# df.iloc[i]['full_text']='@usuario @usuario Pon orden mi capi, esto es inaceptable.'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Mas populismo con tu feminismo de mentiras.'
# df.iloc[i]['full_text']='@usuario @usuario url'
# df.iloc[i]['full_text']='@usuario @usuario OjO a todos que aplauden. Mañana puede ser la nueva víctima que llevar a la hoguera.'
# df.iloc[i]['full_text']='@usuario @usuario Own that bald fraud'
# df.iloc[i]['full_text']='@usuario @usuario Vaya Mundial te has cascao e teta, menudos humitos te gastas'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos levantadas celebrando tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario @usuario Cierra la puerta al salir.'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón azul emoji  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario Estamos TODAS con vosotras  emoji corazón morado emoji  emoji corazón morado emoji  emoji corazón morado emoji  emoji bíceps flexionado emoji  emoji bíceps flexionado emoji  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario Rubiales tiene demasiada cara.. Podríais salir todas a dejarle en su sitio.'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  así es muy bien otra cosa digo también están tardando los futbolistas españoles y no españoles a defenderla también luego se les llena la boca con otras cosas muy grande alexia me quito el sombrero'
# df.iloc[i]['full_text']='@usuario @usuario Estamos todas en esto.\nSi tocan a una, nos tocan a todas.'
# df.iloc[i]['full_text']='@usuario @usuario Culerda'
# df.iloc[i]['full_text']='@usuario @usuario Big  emoji apretón de manos emoji  url'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel oscuro medio emoji  juntos!'
# df.iloc[i]['full_text']='@usuario @usuario Strong reactions  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario Tengo un amigo que busca trabajo ya  url'
# df.iloc[i]['full_text']='@usuario @usuario Bien Alexia! hay que apoyar a la verdad sin miedo url'
# df.iloc[i]['full_text']='@usuario @usuario PUES VALE'
# df.iloc[i]['full_text']='@usuario @usuario url'
# df.iloc[i]['full_text']="@usuario @usuario A veure si ara no t'abaixes els pantalons i prens exemple de les teves companyes Mapi León, Patri Guijarro i Clàudia Pina."
# df.iloc[i]['full_text']='@usuario @usuario Todo vale para hacer daño España'
# df.iloc[i]['full_text']='@usuario @usuario Ya vienen las hienas.'
# df.iloc[i]['full_text']='@usuario @usuario Sha acabat quina cosa? Deixareu la selecció espanyola totes les jugadores?'
# df.iloc[i]['full_text']='@usuario @usuario @usuario hashtag se acabo'
# df.iloc[i]['full_text']='@usuario @usuario @usuario @usuario El cambio va a llegar si o si! emoji balón de fútbol emoji  emoji portería emoji  emoji persona maga emoji \u200d emoji persona haciendo malabares emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario SE ACABO  emoji corazón morado emoji  emoji corazón morado emoji  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario url'
# ...
# df.iloc[i]['full_text']='@usuario &amp; url'
# df.iloc[i]['full_text']='@usuario Mintiendo tb?'
# df.iloc[i]['full_text']='@usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario Pues vale  emoji cara revolviéndose de la risa emoji  emoji cara revolviéndose de la risa emoji  emoji cara revolviéndose de la risa emoji'
# df.iloc[i]['full_text']='@usuario Bueno en todo lo que se dice todo, no. Si no pregúntaselo a Mapi, Patri y Pina.'
# df.iloc[i]['full_text']='@usuario Siempre tarde Laia..cierra la puerta cuándo te vayas al Arsenal  emoji rata emoji  emoji rata emoji  emoji rata emoji'
# df.iloc[i]['full_text']='@usuario Ese es el gran tema, juntas... hashtag seacabo hashtag seacabó juntas y juntos'
# df.iloc[i]['full_text']='@usuario Golpista cobarde?'
# df.iloc[i]['full_text']='@usuario Bravas  emoji corazón morado emoji  ! CAMPEONAS  emoji trofeo emoji !'
# df.iloc[i]['full_text']='@usuario Si Laia, Jennifer lo pasó fatal  ya se vió en el vestuario y en el autocar Coll lloraba de pena'
# df.iloc[i]['full_text']='@usuario Señor rubiales, a tus hijas tenían que meter en un furgón negro, haber que hacías desgraciado, que eres un calvo de mierda, la verdad duele pero la realidad mucho más, prevalecerá de por vida emoji cara sonriendo emoji  emoji jarras de cerveza brindando emoji'
# df.iloc[i]['full_text']='@usuario Deberíais filtrar todo lo que sabéis del Torrente Rubiales y el quebrantahuesos del Vilda. El mundo tiene que saberlo.'
# df.iloc[i]['full_text']='@usuario @usuario Hay que dejar los estadios vacíos este fin de semana y que esto sea noticia en el mundo entero!'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Menudo circo todo, vergonzoso  emoji cara de payaso emoji'
# df.iloc[i]['full_text']='@usuario @usuario Estoy con. Vosotras, estoy con jennifer hermoso\n\nEs de vergüenza que esta persona presida la federacion\n\nJenni  ESTOY CONTIGO'
# df.iloc[i]['full_text']='@usuario @usuario Todos estamos unidas, todo el mundo está de vuestro lado, no calleis más sin miedo a nada, a muerte con vosotrasss'
# df.iloc[i]['full_text']='@usuario @usuario Honor'
# df.iloc[i]['full_text']='@usuario @usuario eres la mejor  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji bíceps flexionado emoji  emoji bíceps flexionado emoji  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario Mi jefa'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel oscuro medio emoji  emoji manos aplaudiendo tono de piel oscuro medio emoji  emoji manos aplaudiendo tono de piel oscuro medio emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji  emoji corazón blanco emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Grande jefa  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grandee!'
# df.iloc[i]['full_text']='@usuario @usuario que orgullo que vistas el escudo que defiendo, siempre contigo jefa  emoji puño cerrado emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji  emoji bandera españa emoji'
# df.iloc[i]['full_text']='@usuario @usuario Jefa  emoji corazón blanco emoji  emoji corazón blanco emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande, Jefa  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Brava Claudia. Más orgulloso si cava de ti. Vecina impecable'
# df.iloc[i]['full_text']='@usuario @usuario Mejor emoji no has podido usar. Panda de payasos  emoji cara de payaso emoji  emoji cara de payaso emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro medio emoji  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji señal de aseo para mujeres emoji  emoji señal de aseo para mujeres emoji  emoji bíceps flexionado tono de piel claro medio emoji  emoji bíceps flexionado tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Dile clau  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario Enorme Claudia emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Eres muy grande, fin, todas unidas contra todo este circo.'
# df.iloc[i]['full_text']='@usuario @usuario Estamos contigo, estamos con todas uds'
# df.iloc[i]['full_text']='@usuario @usuario es un circo dilo'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Grande Claudia  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji  emoji corazón blanco emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande mi jefa'
# df.iloc[i]['full_text']='@usuario @usuario Grande, Claudia  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji  emoji corazón blanco emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande emoji corazón blanco emoji  emoji corazón blanco emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Con vosotras emoji puño en alto tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande Jefa  emoji manos formando un corazón emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande Clau!!!'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Jefa  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Con todas emoji corazón morado emoji  emoji balón de fútbol emoji  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Juntas  emoji corazón blanco emoji  emoji corazón blanco emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande Claudia  emoji corazón blanco emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario  emoji corazón morado emoji  emoji bíceps flexionado tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Bochornoso!!'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario @usuario ¿Por qué Jenni confirma la versión de Rubiales en este video? url'
# df.iloc[i]['full_text']='@usuario @usuario Claudia, a ver si ahora, en vez de 15, sois 23...'
# df.iloc[i]['full_text']='@usuario @usuario  emoji personas abrazándose emoji  emoji bíceps flexionado emoji  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande Claudia!!!'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Jefa  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario hashtag se acabó'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Esa Sanfernandina!!! Con vosotras y contra el machismo rancio de Rubiales.'
# df.iloc[i]['full_text']='@usuario @usuario Ojalá se vaya este payaso de la @usuario'
# df.iloc[i]['full_text']='@usuario @usuario Clau, por favor bloquea todos los comentarios contrarios que solo le dan idea a los agresores  lo que hizo Rubiales es agresion por dónde lo veas aún y cuando Jenny no haya opuesto resistencia en ese momento.'
# df.iloc[i]['full_text']='@usuario @usuario Acabaremos antes diciendo a quién queréis poner, porque es lo q queréis no? Menudo circo'
# df.iloc[i]['full_text']='@usuario @usuario Claudia eres una crack, pero sabéis que os están utilizando, verdad?'
# df.iloc[i]['full_text']='@usuario @usuario Grande !!! ole tu'
# df.iloc[i]['full_text']='@usuario @usuario Rubiales tendría q haber dimitido.Le tienen q cesar ya.Pero no vi a todas las feministas de pacotilla indignándose de la misma manera por la ley Montero q se sabía q sacaría violadores y rebajaría penas. Sois lo peor. Vergüenza terrible. El rojerío es asqueroso. Sois asquerosas'
# df.iloc[i]['full_text']='@usuario @usuario La noticia que quieren tapar con el tema Rubiales: "Un beneficiado por la ley del sí es sí intenta violar a una mujer en Dos Hermanas".'
# df.iloc[i]['full_text']='@usuario @usuario @usuario  emoji manos aplaudiendo tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario grande'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel oscuro medio emoji  emoji manos aplaudiendo tono de piel oscuro medio emoji  emoji manos aplaudiendo tono de piel oscuro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  GRANDE @usuario . A muerte con vosotras  emoji corazón azul emoji  emoji corazón azul emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande María, siempre contigo Jenni Hermoso!!!  emoji bíceps flexionado emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji bíceps flexionado emoji  emoji bíceps flexionado emoji  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario @usuario enorme emoji manos aplaudiendo tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario grande maria emoji corazón morado emoji  emoji manos aplaudiendo tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón azul claro emoji  emoji corazón azul claro emoji  emoji corazón azul claro emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji cara saludando emoji  emoji puño en alto emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario  emoji manos aplaudiendo tono de piel claro emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji botón de marca de verificación emoji  emoji manos en oración tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario grande  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji  emoji manos aplaudiendo tono de piel claro medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande  emoji corazón rojo emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel medio emoji  emoji manos aplaudiendo tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel medio emoji  emoji manos aplaudiendo tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji bíceps flexionado emoji  emoji pulgar hacia arriba emoji'
# df.iloc[i]['full_text']='@usuario @usuario GRANDES!'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Estamos con vosotras.  emoji bíceps flexionado tono de piel claro emoji hashtag se acabó'
# df.iloc[i]['full_text']='@usuario @usuario  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji manos aplaudiendo tono de piel claro emoji  emoji cara saludando emoji'
# df.iloc[i]['full_text']='@usuario @usuario @usuario  emoji bíceps flexionado tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Grande, María!!!'
# df.iloc[i]['full_text']='@usuario @usuario Vamos!'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Gran Maria!  emoji cara saludando emoji'
# df.iloc[i]['full_text']='@usuario @usuario Gracias María, estamos con todas vosotras aunque no quieran, seguiremos avanzando!!!'
# df.iloc[i]['full_text']='@usuario @usuario 1q url'
# df.iloc[i]['full_text']='@usuario @usuario María'
# df.iloc[i]['full_text']='@usuario @usuario @usuario  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji personas abrazándose emoji'
# df.iloc[i]['full_text']='@usuario @usuario El fútbol femenino es como la cerveza sin alcohol  emoji cara con manos abrazando emoji'
# df.iloc[i]['full_text']='@usuario @usuario hashtag se acabo. Como hombre estoy cansado de tanto machismo y de tanto abuso. Lo de hoy ha sido sencillamente asqueroso.'
# df.iloc[i]['full_text']='@usuario @usuario url'
# df.iloc[i]['full_text']='@usuario @usuario @usuario Estas MUJERES han iniciado un cambio social, y habrá un antes y un después, de estas CAMPEONAS del Mundo, de todas las MUJERES jugadoras de fútbol y del FEMINISMO en general.\nHoy España entiende mejor, lo que las MUJERES padecen en sus puestos de trabajo, con sus jefes abusones!.'
# df.iloc[i]['full_text']='@usuario @usuario \u200d emoji tirita emoji'
# df.iloc[i]['full_text']='@usuario @usuario  emoji corazón blanco emoji  emoji corazón blanco emoji  emoji corazón blanco emoji'
# df.iloc[i]['full_text']='@usuario @usuario Gracias,Eva el domingo fuisteis un ejemplo para muchas niñas y adolescentes.\nHoy con vuestra posición en contra del patriarcado seréis un referente,para muchas es un orgullo ver que no os dejáis humillar.\nOs necesitamos os necesitan  emoji bíceps flexionado emoji'
# df.iloc[i]['full_text']='@usuario @usuario Graciasss'
# df.iloc[i]['full_text']='@usuario @usuario Grande!!  emoji manos aplaudiendo emoji'
# df.iloc[i]['full_text']='@usuario @usuario NI UN PASO ATRÁS. Por las que estuvieron, por las que estáis, por las que estarán.'
# df.iloc[i]['full_text']='@usuario @usuario @usuario  emoji corazón morado emoji  emoji bíceps flexionado tono de piel medio emoji'
# df.iloc[i]['full_text']='@usuario @usuario Z url'
# df.iloc[i]['full_text']='@usuario @usuario Doblemente campeona!!! Estamos con vosotras!!'
# df.iloc[i]['full_text']='@usuario @usuario Brava!! Siempre con vosotras! CAMPEONAS!  emoji trofeo emoji  emoji medalla deportiva emoji  emoji corazón morado emoji'
# df.iloc[i]['full_text']='@usuario @usuario Y después de ver esto, ¿Te reafirmas en estar con ella en la mentira? Patéticas\nurl'

# %%
lang_dict
# Out:
# {'en': [0,
#   3,
#   7,
#   15,
#   21,
#   22,
#   24,
#   34,
#   39,
#   40,
#   47,
#   50,
#   53,
#   60,
#   64,
#   69,
#   73,
#   77,
#   81,
#   89,
#   96,
#   104,
#   127,
#   132,
#   137,
#   139,
#   142,
#   143,
#   144,
#   150,
#   160,
#   164,
#   166,
#   170,
#   206,
#   218,
#   220,
#   221,
#   222,
#   223,
#   228,
#   230,
#   245,
#   254,
#   256,
#   261,
#   262,
#   263,
#   266,
#   267,
#   268,
#   269,
#   270,
#   271,
#   273,
#   275,
#   276,
#   277,
#   279,
#   280,
#   288,
#   291,
#   294,
#   295,
#   296,
#   299,
#   304,
#   312,
#   316,
#   321,
#   322,
#   323,
#   327,
#   330,
#   332,
#   337,
#   339,
#   341,
#   346,
#   347,
#   349,
#   352,
#   469,
#   511,
#   529,
#   584,
#   585,
#   601,
#   697,
#   722,
#   728,
#   744,
#   755,
#   773,
#   872,
#   877,
#   902,
#   944,
#   960,
#   970,
#   975,
#   979,
#   982,
#   1009,
#   1030,
#   1065,
#   1077,
#   1098,
#   1166,
#   1167,
#   1168,
#   1171,
#   1172,
#   1174,
#   1175,
#   1176,
#   1177,
#   1178,
#   1179,
#   1180,
#   1181,
#   1182,
#   1183,
#   1184,
#   1185,
#   1186,
#   1188,
#   1189,
#   1190,
#   1191,
#   1193,
#   1195,
#   1196,
#   1197,
#   1198,
#   1200,
#   1201,
#   1202,
#   1203,
#   1204,
#   1205,
#   1206,
#   1208,
#   1209,
#   1210,
#   1212,
#   1214,
#   1215,
#   1216,
#   1217,
#   1219,
#   1220,
#   1221,
#   1222,
#   1223,
#   1224,
#   1225,
#   1226,
#   1228,
#   1229,
#   1230,
#   1231,
#   1232,
#   1233,
#   1234,
#   1235,
#   1236,
#   1237,
#   1239,
#   1240,
#   1241,
#   1243,
#   1244,
#   1246,
#   1247,
#   1248,
#   1253,
#   1254,
#   1255,
#   1257,
#   1258,
#   1259,
#   1262,
#   1268,
#   1270,
#   1271,
#   1272,
#   1273,
#   1276,
#   1277,
#   1280,
#   1282,
#   1284,
#   1285,
#   1286,
#   1288,
#   1289,
#   1290,
#   1291,
#   1292,
#   1293,
#   1294,
#   1295,
#   1297,
#   1298,
#   1302,
#   1303,
#   1305,
#   1306,
#   1308,
#   1313,
#   1315,
#   1316,
#   1317,
#   1320,
#   1321,
#   1323,
#   1325,
#   1326,
#   1327,
#   1328,
#   1329,
#   1331,
#   1332,
#   1333,
#   1336,
#   1337,
#   1338,
#   1342,
#   1345,
#   1348,
#   1349,
#   1351,
#   1352,
#   1356,
#   1357,
#   1361,
#   1362,
#   1365,
#   1366,
#   1367,
#   1380,
#   1387,
#   1390,
#   1395,
#   1396,
#   1403,
#   1412,
#   1429,
#   1447,
#   1456,
#   1486,
#   1494,
#   1535,
#   1553,
#   1568,
#   1569,
#   1571,
#   1572,
#   1574,
#   1575,
#   1576,
#   1588,
#   1592,
#   1593,
#   1598,
#   1599,
#   1602,
#   1605,
#   1607,
#   1609,
#   1614,
#   1615,
#   1619,
#   1620,
#   1621,
#   1622,
#   1623,
#   1627,
#   1628,
#   1631,
#   1634,
#   1635,
#   1636,
#   1637,
#   1639,
#   1643,
#   1644,
#   1645,
#   1647,
#   1655,
#   1657,
#   1659,
#   1661,
#   1665,
#   1666,
#   1667,
#   1669,
#   1674,
#   1679,
#   1690,
#   1691,
#   1692,
#   1694,
#   1696,
#   1698,
#   1699,
#   1702,
#   1703,
#   1704,
#   1705,
#   1706,
#   1709,
#   1712,
#   1721,
#   1724,
#   1726,
#   1739,
#   1744,
#   1748,
#   1751,
#   1753,
#   1755,
#   1758,
#   1759,
#   1765,
#   1769,
#   1770,
#   1774,
#   1782,
#   1790,
#   1795,
#   1807,
#   1846,
#   1856,
#   1859,
#   1864,
#   1869,
#   1870,
#   1916,
#   1954,
#   1960,
#   1977,
#   2002,
#   2063,
#   2081,
#   2085,
#   2134,
#   2210,
#   2212,
#   2218,
#   2230,
#   2243,
#   2248,
#   2277,
#   2278,
#   2293,
#   2303,
#   2304,
#   2310,
#   2330],
#  'es': [1,
#   2,
#   6,
#   10,
#   11,
#   16,
#   18,
#   19,
#   23,
#   25,
#   27,
#   28,
#   29,
#   36,
#   37,
#   38,
#   42,
#   43,
#   44,
#   46,
#   52,
#   54,
#   55,
#   56,
#   57,
#   58,
#   61,
#   63,
#   65,
#   66,
#   67,
#   68,
#   70,
#   71,
#   72,
#   75,
#   78,
#   79,
#   82,
#   83,
#   84,
#   85,
#   86,
#   87,
#   88,
#   90,
#   91,
#   93,
#   94,
#   95,
#   97,
#   98,
#   102,
#   103,
#   106,
#   107,
#   108,
#   109,
#   110,
#   112,
#   113,
#   114,
#   117,
#   118,
#   119,
#   120,
#   121,
#   122,
#   126,
#   128,
#   129,
#   130,
#   131,
#   133,
#   134,
#   135,
#   138,
#   140,
#   145,
#   147,
#   148,
#   149,
#   151,
#   152,
#   154,
#   156,
#   157,
#   159,
#   162,
#   163,
#   165,
#   167,
#   168,
#   169,
#   171,
#   172,
#   173,
#   174,
#   175,
#   177,
#   178,
#   179,
#   180,
#   181,
#   183,
#   184,
#   185,
#   186,
#   187,
#   189,
#   191,
#   192,
#   193,
#   194,
#   195,
#   196,
#   197,
#   198,
#   199,
#   200,
#   201,
#   202,
#   203,
#   204,
#   205,
#   207,
#   208,
#   209,
#   210,
#   211,
#   212,
#   214,
#   215,
#   216,
#   219,
#   224,
#   226,
#   227,
#   229,
#   231,
#   232,
#   234,
#   235,
#   237,
#   238,
#   239,
#   240,
#   241,
#   242,
#   244,
#   246,
#   248,
#   249,
#   251,
#   252,
#   253,
#   255,
#   257,
#   258,
#   260,
#   264,
#   265,
#   274,
#   278,
#   281,
#   282,
#   283,
#   285,
#   286,
#   290,
#   292,
#   297,
#   298,
#   302,
#   303,
#   305,
#   306,
#   307,
#   309,
#   310,
#   311,
#   313,
#   314,
#   315,
#   317,
#   319,
#   320,
#   324,
#   325,
#   326,
#   328,
#   329,
#   331,
#   333,
#   334,
#   335,
#   336,
#   340,
#   342,
#   343,
#   344,
#   345,
#   348,
#   350,
#   351,
#   354,
#   362,
#   364,
#   365,
#   368,
#   369,
#   370,
#   372,
#   375,
#   376,
#   378,
#   379,
#   380,
#   382,
#   383,
#   384,
#   386,
#   387,
#   388,
#   389,
#   392,
#   393,
#   394,
#   396,
#   397,
#   398,
#   399,
#   400,
#   401,
#   402,
#   403,
#   404,
#   407,
#   409,
#   411,
#   412,
#   413,
#   415,
#   416,
#   419,
#   421,
#   422,
#   423,
#   424,
#   425,
#   426,
#   427,
#   428,
#   429,
#   430,
#   433,
#   434,
#   436,
#   437,
#   438,
#   439,
#   440,
#   444,
#   445,
#   446,
#   447,
#   448,
#   449,
#   450,
#   455,
#   456,
#   457,
#   461,
#   462,
#   464,
#   467,
#   468,
#   470,
#   472,
#   475,
#   476,
#   478,
#   479,
#   480,
#   481,
#   482,
#   488,
#   489,
#   491,
#   493,
#   494,
#   495,
#   501,
#   502,
#   503,
#   505,
#   508,
#   514,
#   515,
#   516,
#   517,
#   518,
#   519,
#   520,
#   521,
#   523,
#   524,
#   525,
#   527,
#   528,
#   530,
#   531,
#   532,
#   533,
#   537,
#   538,
#   539,
#   543,
#   544,
#   545,
#   548,
#   549,
#   550,
#   553,
#   554,
#   555,
#   556,
#   557,
#   558,
#   559,
#   564,
#   565,
#   572,
#   573,
#   575,
#   576,
#   587,
#   592,
#   594,
#   605,
#   609,
#   626,
#   627,
#   631,
#   632,
#   638,
#   644,
#   651,
#   655,
#   657,
#   659,
#   664,
#   667,
#   668,
#   669,
#   675,
#   676,
#   678,
#   680,
#   682,
#   689,
#   690,
#   709,
#   715,
#   716,
#   717,
#   718,
#   719,
#   720,
#   721,
#   726,
#   729,
#   735,
#   739,
#   741,
#   743,
#   746,
#   747,
#   748,
#   749,
#   751,
#   753,
#   758,
#   759,
#   760,
#   762,
#   767,
#   769,
#   770,
#   777,
#   782,
#   784,
#   785,
#   787,
#   788,
#   792,
#   794,
#   795,
#   796,
#   798,
#   799,
#   800,
#   801,
#   805,
#   807,
#   808,
#   811,
#   813,
#   815,
#   818,
#   820,
#   826,
#   831,
#   833,
#   842,
#   845,
#   849,
#   850,
#   851,
#   852,
#   854,
#   855,
#   856,
#   859,
#   862,
#   863,
#   865,
#   866,
#   867,
#   869,
#   871,
#   882,
#   884,
#   885,
#   886,
#   896,
#   900,
#   904,
#   905,
#   906,
#   907,
#   908,
#   909,
#   911,
#   913,
#   914,
#   915,
#   918,
#   919,
#   920,
#   921,
#   922,
#   923,
#   924,
#   925,
#   926,
#   928,
#   929,
#   930,
#   931,
#   932,
#   933,
#   934,
#   936,
#   937,
#   938,
#   939,
#   940,
#   941,
#   942,
#   945,
#   946,
#   949,
#   950,
#   952,
#   954,
#   955,
#   956,
#   957,
#   959,
#   962,
#   964,
#   966,
#   971,
#   976,
#   977,
#   981,
#   984,
#   985,
#   988,
#   990,
#   991,
#   992,
#   993,
#   994,
#   995,
#   996,
#   998,
#   999,
#   1001,
#   1003,
#   1005,
#   1006,
#   1007,
#   1011,
#   1012,
#   1014,
#   1015,
#   1019,
#   1020,
#   1021,
#   1025,
#   1029,
#   1031,
#   1032,
#   1037,
#   1038,
#   1040,
#   1041,
#   1043,
#   1046,
#   1047,
#   1049,
#   1051,
#   1052,
#   1055,
#   1057,
#   1059,
#   1061,
#   1062,
#   1064,
#   1066,
#   1068,
#   1070,
#   1071,
#   1074,
#   1075,
#   1078,
#   1080,
#   1081,
#   1082,
#   1083,
#   1090,
#   1093,
#   1094,
#   1095,
#   1101,
#   1104,
#   1105,
#   1106,
#   1107,
#   1109,
#   1111,
#   1112,
#   1113,
#   1115,
#   1117,
#   1119,
#   1121,
#   1123,
#   1124,
#   1126,
#   1128,
#   1129,
#   1130,
#   1131,
#   1132,
#   1133,
#   1134,
#   1135,
#   1136,
#   1137,
#   1140,
#   1141,
#   1142,
#   1143,
#   1144,
#   1145,
#   1146,
#   1147,
#   1148,
#   1149,
#   1150,
#   1151,
#   1152,
#   1153,
#   1154,
#   1155,
#   1156,
#   1157,
#   1159,
#   1161,
#   1162,
#   1163,
#   1164,
#   1169,
#   1170,
#   1173,
#   1199,
#   1207,
#   1218,
#   1227,
#   1238,
#   1242,
#   1245,
#   1249,
#   1250,
#   1251,
#   1256,
#   1261,
#   1265,
#   1267,
#   1269,
#   1274,
#   1275,
#   1278,
#   1279,
#   1281,
#   1283,
#   1296,
#   1299,
#   1310,
#   1311,
#   1312,
#   1318,
#   1322,
#   1330,
#   1334,
#   1335,
#   1340,
#   1341,
#   1344,
#   1346,
#   1347,
#   1350,
#   1353,
#   1354,
#   1355,
#   1360,
#   1373,
#   1381,
#   1384,
#   1385,
#   1389,
#   1391,
#   1392,
#   1393,
#   1397,
#   1399,
#   1401,
#   1402,
#   1405,
#   1413,
#   1416,
#   1418,
#   1421,
#   1426,
#   1430,
#   1431,
#   1434,
#   1438,
#   1439,
#   1442,
#   1443,
#   1446,
#   1448,
#   1449,
#   1450,
#   1457,
#   1458,
#   1460,
#   1463,
#   1467,
#   1468,
#   1470,
#   1471,
#   1476,
#   1477,
#   1479,
#   1483,
#   1489,
#   1491,
#   1499,
#   1500,
#   1502,
#   1504,
#   1505,
#   1509,
#   1510,
#   1512,
#   1516,
#   1517,
#   1518,
#   1520,
#   1521,
#   1524,
#   1525,
#   1526,
#   1527,
#   1528,
#   1529,
#   1530,
#   1531,
#   1533,
#   1534,
#   1537,
#   1543,
#   1544,
#   1545,
#   1548,
#   1549,
#   1555,
#   1557,
#   1559,
#   1561,
#   1563,
#   1564,
#   1566,
#   1567,
#   1570,
#   1577,
#   1578,
#   1579,
#   1583,
#   1584,
#   1585,
#   1586,
#   1587,
#   1589,
#   1591,
#   1594,
#   1600,
#   1603,
#   1604,
#   1606,
#   1610,
#   1612,
#   1616,
#   1618,
#   1624,
#   1626,
#   1629,
#   1630,
#   1632,
#   1633,
#   1640,
#   1641,
#   1646,
#   1648,
#   1649,
#   1650,
#   1651,
#   1652,
#   1653,
#   1654,
#   1656,
#   1660,
#   1662,
#   1663,
#   1664,
#   1668,
#   1670,
#   1671,
#   1672,
#   1673,
#   1675,
#   1676,
#   1677,
#   1678,
#   1680,
#   1682,
#   1683,
#   1684,
#   1685,
#   1686,
#   1687,
#   1688,
#   1689,
#   1693,
#   1697,
#   1700,
#   1701,
#   1707,
#   1710,
#   1714,
#   1715,
#   1716,
#   1717,
#   1718,
#   1719,
#   1720,
#   1722,
#   1723,
#   1725,
#   1727,
#   1729,
#   1731,
#   1732,
#   1733,
#   1735,
#   1736,
#   1737,
#   1738,
#   1740,
#   1741,
#   1742,
#   1743,
#   1745,
#   1746,
#   1747,
#   1749,
#   1752,
#   1754,
#   1756,
#   1757,
#   1760,
#   1761,
#   1762,
#   1764,
#   1766,
#   1767,
#   1771,
#   1773,
#   1775,
#   1780,
#   1785,
#   1786,
#   1787,
#   1792,
#   1793,
#   1797,
#   1798,
#   1799,
#   1803,
#   1808,
#   1809,
#   1811,
#   1812,
#   1813,
#   1814,
#   1816,
#   1817,
#   1818,
#   1819,
#   1820,
#   1821,
#   1822,
#   1823,
#   1824,
#   1826,
#   1827,
#   1829,
#   1834,
#   1839,
#   1840,
#   1841,
#   1845,
#   1847,
#   1848,
#   1850,
#   1851,
#   1852,
#   1854,
#   1857,
#   1860,
#   1863,
#   1866,
#   1868,
#   1871,
#   1872,
#   1873,
#   1875,
#   1876,
#   1877,
#   1879,
#   1882,
#   1883,
#   1884,
#   1885,
#   1886,
#   1887,
#   1890,
#   1891,
#   1892,
#   1895,
#   1896,
#   1897,
#   1901,
#   1903,
#   1904,
#   1906,
#   1907,
#   1908,
#   1910,
#   1912,
#   1919,
#   1921,
#   1922,
#   1923,
#   1924,
#   1925,
#   1926,
#   1927,
#   1928,
#   1929,
#   1930,
#   1931,
#   1932,
#   1933,
#   1934,
#   1935,
#   1936,
#   1937,
#   1938,
#   1939,
#   1940,
#   1941,
#   1942,
#   1943,
#   1944,
#   1945,
#   1946,
#   1947,
#   1948,
#   1949,
#   1950,
#   1951,
#   1952,
#   1953,
#   1955,
#   1959,
#   1961,
#   1962,
#   1963,
#   1965,
#   1966,
#   1967,
#   1968,
#   1970,
#   1971,
#   1974,
#   1975,
#   1976,
#   1982,
#   1983,
#   1984,
#   1986,
#   1991,
#   1992,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2003,
#   2005,
#   2007,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2015,
#   2017,
#   2018,
#   2019,
#   2020,
#   2021,
#   2022,
#   2023,
#   2025,
#   2026,
#   2027,
#   2028,
#   2029,
#   2030,
#   2031,
#   2032,
#   2033,
#   2035,
#   2036,
#   2037,
#   2038,
#   2039,
#   2040,
#   2041,
#   2042,
#   2043,
#   2044,
#   2045,
#   2046,
#   2049,
#   2051,
#   2052,
#   2054,
#   2055,
#   2056,
#   2057,
#   ...],
#  'sl': [4,
#   17,
#   20,
#   74,
#   80,
#   100,
#   105,
#   115,
#   141,
#   161,
#   614,
#   978,
#   980,
#   983,
#   987,
#   1000,
#   1018,
#   1022,
#   1024,
#   1027,
#   1028,
#   1036,
#   1045,
#   1050,
#   1053,
#   1054,
#   1056,
#   1073,
#   1084,
#   1086,
#   1087,
#   1100,
#   1102,
#   1120,
#   1138,
#   1139,
#   1158,
#   1406,
#   1478,
#   1550,
#   1551,
#   1611,
#   1625,
#   1768,
#   1861,
#   1894,
#   1915,
#   1918,
#   2185,
#   2187,
#   2192,
#   2193,
#   2196,
#   2198,
#   2200,
#   2202,
#   2217,
#   2220,
#   2223,
#   2234,
#   2236,
#   2239,
#   2252,
#   2254,
#   2259,
#   2260,
#   2288,
#   2464,
#   2465,
#   2472,
#   2490,
#   2514,
#   2532,
#   2533,
#   2534,
#   2538,
#   2539,
#   2540,
#   2541,
#   2544,
#   2546,
#   2555,
#   2558,
#   2569],
#  'pt': [5,
#   8,
#   12,
#   13,
#   14,
#   26,
#   30,
#   31,
#   33,
#   35,
#   41,
#   48,
#   51,
#   62,
#   76,
#   101,
#   111,
#   123,
#   125,
#   136,
#   153,
#   155,
#   182,
#   188,
#   213,
#   338,
#   357,
#   359,
#   360,
#   361,
#   363,
#   366,
#   367,
#   371,
#   373,
#   374,
#   377,
#   381,
#   385,
#   391,
#   395,
#   405,
#   406,
#   408,
#   410,
#   417,
#   418,
#   420,
#   431,
#   432,
#   441,
#   442,
#   443,
#   451,
#   452,
#   453,
#   458,
#   460,
#   465,
#   466,
#   471,
#   473,
#   474,
#   477,
#   483,
#   484,
#   485,
#   486,
#   487,
#   490,
#   492,
#   496,
#   497,
#   498,
#   499,
#   504,
#   506,
#   507,
#   509,
#   510,
#   512,
#   513,
#   522,
#   526,
#   535,
#   536,
#   540,
#   541,
#   542,
#   546,
#   547,
#   551,
#   552,
#   568,
#   582,
#   633,
#   848,
#   965,
#   968,
#   973,
#   974,
#   997,
#   1010,
#   1039,
#   1044,
#   1063,
#   1072,
#   1079,
#   1092,
#   1110,
#   1114,
#   1118,
#   1122,
#   1125,
#   1165,
#   1304,
#   1363,
#   1368,
#   1386,
#   1400,
#   1408,
#   1422,
#   1424,
#   1425,
#   1432,
#   1435,
#   1441,
#   1454,
#   1459,
#   1482,
#   1488,
#   1490,
#   1492,
#   1495,
#   1503,
#   1506,
#   1514,
#   1538,
#   1546,
#   1552,
#   1556,
#   1560,
#   1562,
#   1565,
#   1734,
#   1763,
#   1838,
#   1878,
#   1993,
#   2067,
#   2068,
#   2071,
#   2072,
#   2073,
#   2075,
#   2076,
#   2079,
#   2082,
#   2087,
#   2089,
#   2091,
#   2092,
#   2093,
#   2094,
#   2095,
#   2096,
#   2098,
#   2099,
#   2102,
#   2104,
#   2106,
#   2108,
#   2110,
#   2111,
#   2114,
#   2115,
#   2117,
#   2118,
#   2120,
#   2121,
#   2122,
#   2126,
#   2129,
#   2131,
#   2132,
#   2133,
#   2135,
#   2136,
#   2138,
#   2139,
#   2141,
#   2145,
#   2148,
#   2149,
#   2150,
#   2152,
#   2154,
#   2167,
#   2169,
#   2173,
#   2174,
#   2175,
#   2182,
#   2269,
#   2333,
#   2343,
#   2347,
#   2355,
#   2361,
#   2366,
#   2370,
#   2375,
#   2398,
#   2480,
#   2565,
#   2571],
#  'it': [9,
#   45,
#   49,
#   99,
#   116,
#   124,
#   146,
#   176,
#   190,
#   217,
#   225,
#   233,
#   236,
#   247,
#   259,
#   272,
#   287,
#   289,
#   293,
#   301,
#   308,
#   318,
#   574,
#   581,
#   591,
#   598,
#   604,
#   608,
#   621,
#   624,
#   653,
#   662,
#   670,
#   674,
#   677,
#   685,
#   699,
#   706,
#   707,
#   708,
#   712,
#   727,
#   731,
#   738,
#   745,
#   756,
#   763,
#   764,
#   765,
#   766,
#   768,
#   771,
#   772,
#   774,
#   775,
#   776,
#   778,
#   779,
#   780,
#   781,
#   783,
#   786,
#   789,
#   790,
#   791,
#   793,
#   797,
#   803,
#   804,
#   806,
#   809,
#   810,
#   814,
#   817,
#   819,
#   821,
#   822,
#   825,
#   827,
#   828,
#   830,
#   832,
#   834,
#   835,
#   836,
#   837,
#   839,
#   840,
#   841,
#   843,
#   844,
#   846,
#   847,
#   857,
#   858,
#   860,
#   861,
#   868,
#   870,
#   873,
#   874,
#   875,
#   879,
#   880,
#   881,
#   883,
#   888,
#   889,
#   890,
#   891,
#   892,
#   893,
#   895,
#   897,
#   899,
#   901,
#   903,
#   910,
#   912,
#   916,
#   917,
#   927,
#   935,
#   943,
#   947,
#   948,
#   953,
#   958,
#   961,
#   963,
#   967,
#   969,
#   972,
#   986,
#   989,
#   1004,
#   1008,
#   1016,
#   1017,
#   1023,
#   1026,
#   1033,
#   1035,
#   1042,
#   1048,
#   1058,
#   1060,
#   1067,
#   1069,
#   1076,
#   1088,
#   1089,
#   1091,
#   1096,
#   1097,
#   1099,
#   1103,
#   1108,
#   1116,
#   1127,
#   1194,
#   1211,
#   1263,
#   1264,
#   1339,
#   1343,
#   1452,
#   1493,
#   1581,
#   1590,
#   1595,
#   1596,
#   1597,
#   1608,
#   1617,
#   1638,
#   1642,
#   1658,
#   1728,
#   1730,
#   1776,
#   1777,
#   1779,
#   1783,
#   1784,
#   1789,
#   1791,
#   1794,
#   1796,
#   1800,
#   1804,
#   1805,
#   1810,
#   1815,
#   1835,
#   1836,
#   1842,
#   1843,
#   1844,
#   1853,
#   1855,
#   1858,
#   1862,
#   1865,
#   1874,
#   1880,
#   1898,
#   1899,
#   1902,
#   1911,
#   1913,
#   1917,
#   1920,
#   2047,
#   2086,
#   2088,
#   2097,
#   2103,
#   2112,
#   2113,
#   2116,
#   2125,
#   2127,
#   2130,
#   2140,
#   2142,
#   2153,
#   2177,
#   2213,
#   2216,
#   2224,
#   2232,
#   2235,
#   2237,
#   2241,
#   2266,
#   2285,
#   2306,
#   2307,
#   2308,
#   2309,
#   2313,
#   2315,
#   2319,
#   2320,
#   2323,
#   2327,
#   2328,
#   2331,
#   2332,
#   2334,
#   2335,
#   2344,
#   2345,
#   2348,
#   2351,
#   2352,
#   2353,
#   2354,
#   2360,
#   2362,
#   2365,
#   2369,
#   2371,
#   2373,
#   2376,
#   2379,
#   2392,
#   2395,
#   2416,
#   2458,
#   2459,
#   2462,
#   2466,
#   2467,
#   2468,
#   2469,
#   2470,
#   2471,
#   2473,
#   2475,
#   2476,
#   2477,
#   2478,
#   2479,
#   2481,
#   2482,
#   2483,
#   2484,
#   2487,
#   2488,
#   2489,
#   2491,
#   2492,
#   2493,
#   2494,
#   2495,
#   2496,
#   2497,
#   2498,
#   2499,
#   2500,
#   2501,
#   2502,
#   2503,
#   2504,
#   2506,
#   2507,
#   2509,
#   2512,
#   2513,
#   2515,
#   2516,
#   2522],
#  'de': [32,
#   243,
#   1371,
#   1375,
#   1376,
#   1378,
#   1379,
#   1394,
#   1411,
#   1414,
#   1436,
#   1440,
#   1462,
#   1466,
#   1473,
#   1480,
#   1481,
#   1498,
#   1523,
#   1536,
#   1573,
#   1582,
#   1708,
#   1711,
#   1750,
#   1956,
#   1957,
#   1958,
#   1964,
#   1969,
#   1972,
#   1973,
#   1978,
#   1979,
#   1980,
#   1981,
#   1985,
#   1987,
#   1988,
#   1989,
#   1994,
#   2004,
#   2006,
#   2008,
#   2014,
#   2016,
#   2024,
#   2034,
#   2048,
#   2050,
#   2053,
#   2100,
#   2119,
#   2191,
#   2199,
#   2219,
#   2228,
#   2240,
#   2245,
#   2294],
#  'ca': [59,
#   250,
#   353,
#   356,
#   358,
#   390,
#   414,
#   435,
#   454,
#   459,
#   463,
#   500,
#   534,
#   562,
#   563,
#   567,
#   589,
#   590,
#   606,
#   610,
#   611,
#   612,
#   615,
#   616,
#   618,
#   619,
#   620,
#   622,
#   623,
#   628,
#   630,
#   635,
#   640,
#   641,
#   642,
#   646,
#   647,
#   649,
#   650,
#   652,
#   658,
#   661,
#   665,
#   671,
#   681,
#   686,
#   691,
#   692,
#   695,
#   698,
#   700,
#   701,
#   702,
#   703,
#   704,
#   711,
#   714,
#   724,
#   725,
#   734,
#   737,
#   740,
#   754,
#   757,
#   802,
#   812,
#   816,
#   823,
#   824,
#   829,
#   838,
#   853,
#   864,
#   876,
#   878,
#   887,
#   894,
#   898,
#   951,
#   1160,
#   1580,
#   1601,
#   1613,
#   1681,
#   1695,
#   1837,
#   1881,
#   1990,
#   2318,
#   2322,
#   2326,
#   2346,
#   2350,
#   2357,
#   2390,
#   2393,
#   2400,
#   2403,
#   2404,
#   2406,
#   2407,
#   2408,
#   2409,
#   2410,
#   2411,
#   2413,
#   2417,
#   2418,
#   2419,
#   2422,
#   2424,
#   2425,
#   2426,
#   2428,
#   2429,
#   2432,
#   2435,
#   2436,
#   2437,
#   2439,
#   2441,
#   2442,
#   2443,
#   2444,
#   2445,
#   2447,
#   2448,
#   2452],
#  'nl': [92,
#   1187,
#   1192,
#   1213,
#   1260,
#   1266,
#   1287,
#   1301,
#   1307,
#   1309,
#   1314,
#   1364,
#   2536,
#   2543,
#   2566],
#  'sq': [158],
#  'et': [284,
#   300,
#   599,
#   723,
#   1013,
#   1085,
#   1252,
#   1300,
#   1358,
#   1359,
#   1369,
#   1370,
#   1372,
#   1374,
#   1377,
#   1382,
#   1383,
#   1388,
#   1404,
#   1407,
#   1409,
#   1410,
#   1415,
#   1417,
#   1419,
#   1420,
#   1423,
#   1427,
#   1428,
#   1433,
#   1437,
#   1444,
#   1445,
#   1451,
#   1453,
#   1455,
#   1461,
#   1464,
#   1465,
#   1469,
#   1472,
#   1474,
#   1475,
#   1484,
#   1485,
#   1487,
#   1496,
#   1497,
#   1501,
#   1507,
#   1511,
#   1513,
#   1519,
#   1522,
#   1532,
#   1539,
#   1540,
#   1541,
#   1542,
#   1554,
#   1558,
#   2124,
#   2137,
#   2526,
#   2527,
#   2529,
#   2535,
#   2542,
#   2545,
#   2547,
#   2549,
#   2552],
#  'fi': [355,
#   586,
#   705,
#   1319,
#   1324,
#   1772,
#   1778,
#   1781,
#   1788,
#   1801,
#   1802,
#   1806,
#   1825,
#   1828,
#   1830,
#   1831,
#   1832,
#   1833,
#   1849,
#   1867,
#   1888,
#   1889,
#   1893,
#   1900,
#   1905,
#   1909,
#   2525,
#   2562,
#   2563,
#   2568],
#  'tl': [560,
#   561,
#   566,
#   569,
#   570,
#   571,
#   577,
#   578,
#   579,
#   580,
#   583,
#   593,
#   595,
#   596,
#   597,
#   600,
#   602,
#   603,
#   607,
#   617,
#   625,
#   629,
#   634,
#   636,
#   637,
#   639,
#   643,
#   645,
#   648,
#   654,
#   656,
#   660,
#   663,
#   672,
#   679,
#   683,
#   687,
#   688,
#   693,
#   694,
#   696,
#   710,
#   742,
#   750,
#   752,
#   761],
#  'sw': [588, 733, 2412],
#  'id': [613, 684, 732, 1547, 1713, 2553],
#  'tr': [666],
#  'lt': [673],
#  'cy': [713],
#  'hr': [730, 736],
#  'ro': [1002, 1034, 2528, 2530, 2537, 2550, 2557],
#  'da': [1398],
#  'hu': [1508],
#  'so': [1515, 1914, 2215],
#  'sk': [2508]}

# %%
lang_counts
# Out:
# {'en': 361,
#  'es': 1219,
#  'sl': 84,
#  'pt': 216,
#  'it': 314,
#  'de': 60,
#  'ca': 128,
#  'nl': 15,
#  'sq': 1,
#  'et': 72,
#  'fi': 30,
#  'tl': 46,
#  'sw': 3,
#  'id': 6,
#  'tr': 1,
#  'lt': 1,
#  'cy': 1,
#  'hr': 2,
#  'ro': 7,
#  'da': 1,
#  'hu': 1,
#  'so': 3,
#  'sk': 1}

# %%
df.iloc[767]['full_text']
# Out:
# '@catacoll2001 @barnacitizen @Jennihermoso Con Ustedes las jugadoras siempre !!'

# %% [markdown]
# ### Bart (zero-shot)

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
candidate_labels = ["Text is in english", "Text is in spanish", "Text is in italian", "Text is in arabic", "Text is in catalan", "Text is in euskera", "Text is in galician"]

lang_dict = {}

for i in range(len(df)):
    print(f"{df.iloc[i]['full_text']=}")
    try:
        lang_result = classifier(df.iloc[i]['full_text'], candidate_labels)
        lang = lang_result["labels"][0]
        print(f"{lang=}")
    except:
        pass

    if lang not in lang_dict.keys():
        lang_dict[lang] = []
    lang_dict[lang].append(i)

lang_counts = {}
for lang in list(lang_dict.keys()):
    lang_counts[lang] = len(lang_dict[lang])

# %%
lang_counts
